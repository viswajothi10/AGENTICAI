# %%
pip install langchain langchain-text-splitters langchain-community langchain-huggingface faiss-cpu

# %%
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader

# Define 'text' variable with some example content
text = "This is an example text that needs to be split into chunks. It contains multiple sentences and some repetition."

splitter = CharacterTextSplitter(
    chunk_size=30,
    chunk_overlap=2
)
chunks = splitter.split_text(text)
print(chunks)
# Out:
# ['This is an example text that needs to be split into chunks. It contains multiple sentences and some repetition.']

# %%
from langchain_community.vectorstores import FAISS
from langchain_huggingface.embeddings import HuggingFaceEmbeddings
embedding_model= HuggingFaceEmbeddings()
db=FAISS.from_texts(
    chunks,
    embedding_model
)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# MPNetModel LOAD REPORT from: sentence-transformers/all-mpnet-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
results=db.similarity_search(
    "what is clustering?"
)
print(results[0].page_content)
# Out:
# This is an example text that needs to be split into chunks. It contains multiple sentences and some repetition.

# %%
# !pip install langchain-community
from langchain_community.document_loaders import PyPDFLoader
# Use the dummy PDF path created in the previous step
pdf_path = dummy_pdf_path
loader = PyPDFLoader(pdf_path)
documents = loader.load()
documents
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1715/1203508271.py in <cell line: 0>()
#       2 from langchain_community.document_loaders import PyPDFLoader
#       3 # Use the dummy PDF path created in the previous step
# ----> 4 pdf_path = dummy_pdf_path
#       5 loader = PyPDFLoader(pdf_path)
#       6 documents = loader.load()
#
# NameError: name 'dummy_pdf_path' is not defined
