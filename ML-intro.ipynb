# %% [markdown]
# MACHINE LEARNING BASICS

# %%
print("hello jupyter")
# Out:
# hello jupyter

# %% [markdown]
# # types of Ml model
#  regression
#  clasification
#  clustering

# %% [markdown]
# # 1.Regression
# Regression is a type of supervised learning algorithm that is used to predict a continuous target variable based on one or more input features. The goal of regression is to find the best-fitting line or curve that represents the relationship between the input features and the target variable.
#
# steps:
# 1.import the required libraries
# 2.gather all the required data
# ===============================================================
#
#
#
#
#
#
#
# 1.define features[x]and targets[y]
# 2.splitting data into training and testing dataset
# 3.use training to train the model
# 4.use testing data to test the model performance
# 5.visualize the final model

# %%
pip install numpy pandas scikit-learn matplotlib
# Out:
# Requirement already satisfied: numpy in .\.venv-2\Lib\site-packages (2.4.6)
# Requirement already satisfied: pandas in .\.venv-2\Lib\site-packages (3.0.3)
# Requirement already satisfied: scikit-learn in .\.venv-2\Lib\site-packages (1.8.0)
# Requirement already satisfied: matplotlib in .\.venv-2\Lib\site-packages (3.10.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv-2\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\.venv-2\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: scipy>=1.10.0 in .\.venv-2\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in .\.venv-2\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in .\.venv-2\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in .\.venv-2\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\.venv-2\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\.venv-2\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\.venv-2\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in .\.venv-2\Lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in .\.venv-2\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in .\.venv-2\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in .\.venv-2\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np ## linear algebra
import pandas as pd ## data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt ## use to plot the data

# %% [markdown]
# Experimenting with random data

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import numpy as np

# %%
randomdata = np.random.Randomstate(1)
x=10*randomdata.rand(100)
y=2*x-5+randomdata.rand(100)
plt.scatter(x,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 randomdata = np.random.Randomstate(1)
#       2 x=10*randomdata.rand(100)
#       3 y=2*x-5+randomdata.rand(100)
#       4 plt.scatter(x,y)
#
# AttributeError: module 'numpy.random' has no attribute 'Randomstate'

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x|:, np.newaxis,y)
xfit = np.linspace(0,10,1000)
yfit = model.predict(xfit[:, np.newaxis])
plt.scatter(x, y)
plt.plot(xfit, yfit,color='red')
# Out:
#   Cell In[3], line 3
#     model.fit(x|:, np.newaxis,y)
#                 ^
# SyntaxError: invalid syntax
